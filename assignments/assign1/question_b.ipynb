[-1.982121212121212394663416489493,-3.563621245700595796535026238416],
[-2.042727272727273390984237266821,-7.141452657528978953394016571110],
[-2.103333333333333943215848194086,-3.773421071019012362768307866645],
[-2.163939393939394495447459121351,-4.096150044983326132808088004822],
[-2.224545454545455047679070048616,-2.577592316090599133815430832328],
[-2.285151515151515599910680975881,-2.793293072018617095864101429470],
[-2.345757575757576152142291903147,-1.031802580419611814477320876904],
[-2.406363636363636704373902830412,-7.447752028011476177482563798549],
[-2.466969696969697700694723607739,-4.907173481814857574079269397771],
[-2.527575757575757808837124684942,-3.998251678046557344714528881013],
[-2.588181818181818361068735612207,-2.629943698232092064159814981394],
[-2.648787878787879357389556389535,-7.148017871419423130419090739451],
[-2.709393939393939465531957466737,-4.502085095901867894951919879531],
[-2.770000000000000017763568394003,-6.264679768098062595527153462172]
]

points = np.asarray(points)
v = np.asarray([-3., -4.])
b = np.asarray([0.23, 0.15])
t = np.linspace(-1,1,100)

L = np.dot(t.reshape(100,1), v.reshape(1, 2)) + np.tile(b, (100, 1))
plt.plot(L[:, 0], L[:, 1], '--')
plt.plot(points[:,0], points[:,1], '.')
plt.show()

# No y-coords are the same with regard to the line and the points
# Thus you can disregard the x-coords since they are not relevant

y_higher = np.greater(points[:,1], L[:,1])
y_lower = np.less(points[:,1], L[:,1])

print("The number of points above the line is: ", np.sum(y_higher))
print("The number of points below the line is: ", np.sum(y_lower))
# Out:
# The number of points above the line is:  35
# The number of points below the line is:  65

# %% [markdown]
# ## Question B.2
# [10] Plot the points above the line as '+', and points below the line as 'o'. Show your code
#
# ---

# %%
higher_points = []
lower_points = []

for i in range(len(y_higher)):
    if(y_higher[i] == True):
        higher_points.append(points[i])
    else:
        lower_points.append(points[i])

L = np.dot(t.reshape(100,1), v.reshape(1, 2)) + np.tile(b, (100, 1))
plt.plot(L[:, 0], L[:, 1], '--')

higher_points = np.array(higher_points)
plt.plot(higher_points[:,0], higher_points[:,1], '+')

lower_points = np.array(lower_points)
plt.plot(lower_points[:,0], lower_points[:,1], 'o')
plt.show()

# %% [markdown]
# ## Question B.3
# [10] How many are strictly within some distance, which d = 1.0, away from the line? Figure 2
# illustrates the band in which you need to count the points in. You must show your work and code.
#
# ---

# %%
points_in_range = []

for i in range(len(points)):
    y_diff = L[i][1] - points[i][1]
    y_diff = np.absolute(y_diff)
    if y_diff <= 1:
        points_in_range.append(points[i])

points_in_range = np.array(points_in_range)

print("The number of points within d = 1.0 is: ", len(points_in_range))
# Out:
# The number of points within d = 1.0 is:  42
